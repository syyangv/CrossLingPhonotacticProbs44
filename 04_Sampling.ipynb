# %% [markdown]
# # Use randomized language model for each context and each syllable length to sample lexicons

# %% [markdown]
# Modeling after main04.py

# %% [markdown]
# ## Setting up the environment

# %%
import sys
import csv
import pandas as pd
import yaml
import bz2
import numpy as np
from time import gmtime, strftime
from datetime import datetime
pd.set_option('max_rows', 10)
sys.path.insert(0, '04_Sampling_with_randomization/')
from assign_probs_to_words import *
from randomize_language_models_and_sampling import *
print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# ## Meta-parameters

# %%
LanCode = 'tr'
n_phones = '4'
n_vowels = '2'
num_rounds = '11'
sample_num = '3'
write_real_probs = '1'
n_phones = int(n_phones)
n_vowels = int(n_vowels)
num_rounds = int(num_rounds)
num_max_segs = int(num_rounds) - 1
sample_num = int(sample_num)
write_real_probs = bool(int(write_real_probs))

# %% [markdown]
# ## 1. Importing language models and sizes for each syllable length

# %% [markdown]
# ### 1.1 language model

# %%
lm_dict_path = 'language_models/' + LanCode + '.LM.bysyl'
with bz2.open(lm_dict_path) as dbfile:
    lm_dict = yaml.load(dbfile)

# %%
lm_dict
# Out:
# {1: defaultdict(collections.Counter,
#              {((),
#                ()): Counter({('a0', True): 28,
#                        ('aː0', True): 1,
#                        ('b', False): 49,
#                        ('d', False): 55,
#                        ('dʒ', False): 23,
#                        ('e0', True): 12,
#                        ('f', False): 18,
#                        ('g', False): 35,
#                        ('h', False): 36,
#                        ('i0', True): 14,
#                        ('j', False): 32,
#                        ('k', False): 76,
#                        ('l', False): 22,
#                        ('m', False): 28,
#                        ('n', False): 27,
#                        ('o0', True): 10,
#                        ('p', False): 25,
#                        ('s', False): 64,
#                        ('t', False): 53,
#                        ('tʃ', False): 13,
#                        ('u0', True): 8,
#                        ('v', False): 10,
#                        ('y0', True): 7,
#                        ('z', False): 10,
#                        ('œ0', True): 5,
#                        ('ɯ0', True): 4,
#                        ('ɾ', False): 16,
#                        ('ʃ', False): 17,
#                        ('ʒ', False): 2}),
#               (('a0',),
#                ('a0',)): Counter({('b', False): 1,
#                        ('d', False): 1,
#                        ('dʒ', False): 1,
#                        ('f', False): 1,
#                        ('g', False): 1,
#                        ('h', False): 1,
#                        ('hː', False): 2,
#                        ('j', False): 2,
#                        ('k', False): 1,
#                        ('l', False): 2,
#                        ('lː', False): 1,
#                        ('m', False): 1,
#                        ('n', False): 2,
#                        ('s', False): 2,
#                        ('t', False): 1,
#                        ('tʃ', False): 1,
#                        ('v', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 3,
#                        ('ʃ', False): 2}),
#               (('a0', 'b'), ('a0',)): Counter({('d', False): 1}),
#               (('a0', 'b', 'd'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'd'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'dʒ'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'f'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'g'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'h'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'hː'),
#                ('a0',)): Counter({('', False): 1, ('h', False): 1}),
#               (('a0', 'hː', 'h'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'j'),
#                ('a0',)): Counter({('', False): 1, ('n', False): 1}),
#               (('a0', 'j', 'n'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'j', 's'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'k'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'k', 's'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'l'),
#                ('a0',)): Counter({('', False): 1, ('t', False): 1}),
#               (('a0', 'l', 'b'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'l', 'k'), ('a0',)): Counter({('', False): 3}),
#               (('a0', 'l', 'p'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'l', 't'), ('a0',)): Counter({('', False): 3}),
#               (('a0', 'lː'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'm'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'm', 'd'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'm', 'p'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'n'),
#                ('a0',)): Counter({('', False): 1, ('d', False): 1}),
#               (('a0', 'n', 'd'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'n', 's'), ('a0',)): Counter({('', False): 2}),
#               (('a0', 'n', 't'), ('a0',)): Counter({('', False): 2}),
#               (('a0', 'pː', 'j'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 's'),
#                ('a0',)): Counter({('', False): 1, ('k', False): 1}),
#               (('a0', 's', 'k'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 's', 't'), ('a0',)): Counter({('', False): 3}),
#               (('a0', 't'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'tʃ'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'v'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'z'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'ɾ'),
#                ('a0',)): Counter({('', False): 1,
#                        ('t', False): 1,
#                        ('z', False): 1}),
#               (('a0', 'ɾ', 'd'), ('a0',)): Counter({('', False): 2}),
#               (('a0', 'ɾ', 'f'), ('a0',)): Counter({('', False): 3}),
#               (('a0', 'ɾ', 'k'), ('a0',)): Counter({('', False): 3}),
#               (('a0', 'ɾ', 'p'), ('a0',)): Counter({('', False): 3}),
#               (('a0', 'ɾ', 't'), ('a0',)): Counter({('', False): 7}),
#               (('a0', 'ɾ', 'tʃ'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'ɾ', 'z'), ('a0',)): Counter({('', False): 3}),
#               (('a0', 'ɾ', 'ʃ'), ('a0',)): Counter({('', False): 1}),
#               (('a0', 'ʃ'),
#                ('a0',)): Counter({('', False): 1, ('k', False): 1}),
#               (('a0', 'ʃ', 'k'), ('a0',)): Counter({('', False): 1}),
#               (('aː0',), ('aː0',)): Counter({('', False): 1}),
#               (('b',),
#                ()): Counter({('a0', True): 9,
#                        ('aː0', True): 1,
#                        ('e0', True): 11,
#                        ('i0', True): 6,
#                        ('j', False): 1,
#                        ('l', False): 3,
#                        ('o0', True): 9,
#                        ('u0', True): 3,
#                        ('ɯ0', True): 2,
#                        ('ɾ', False): 4}),
#               (('b', 'a0'),
#                ('a0',)): Counter({('', False): 1,
#                        ('j', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('n', False): 1,
#                        ('s', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('b', 'a0', 'j'), ('a0',)): Counter({('', False): 1}),
#               (('b', 'a0', 'k'), ('a0',)): Counter({('', False): 1}),
#               (('b', 'a0', 'l'), ('a0',)): Counter({('', False): 1}),
#               (('b', 'a0', 'n'), ('a0',)): Counter({('t', False): 1}),
#               (('b', 'a0', 's'), ('a0',)): Counter({('', False): 1}),
#               (('b', 'a0', 'z'), ('a0',)): Counter({('', False): 1}),
#               (('b', 'a0', 'ɾ'), ('a0',)): Counter({('', False): 1}),
#               (('b', 'a0', 'ʃ'), ('a0',)): Counter({('', False): 1}),
#               (('b', 'aː0'), ('aː0',)): Counter({('', False): 1}),
#               (('b', 'e0'),
#                ('e0',)): Counter({('', False): 1,
#                        ('j', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('lː', False): 1,
#                        ('s', False): 2,
#                        ('t', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('b', 'e0', 'j'), ('e0',)): Counter({('', False): 1}),
#               (('b', 'e0', 'k'), ('e0',)): Counter({('', False): 1}),
#               (('b', 'e0', 'l'), ('e0',)): Counter({('', False): 1}),
#               (('b', 'e0', 'lː'), ('e0',)): Counter({('', False): 1}),
#               (('b', 'e0', 's'),
#                ('e0',)): Counter({('', False): 1, ('t', False): 1}),
#               (('b', 'e0', 't'), ('e0',)): Counter({('', False): 1}),
#               (('b', 'e0', 'z'), ('e0',)): Counter({('', False): 1}),
#               (('b', 'e0', 'ɾ'), ('e0',)): Counter({('', False): 1}),
#               (('b', 'e0', 'ʃ'), ('e0',)): Counter({('', False): 1}),
#               (('b', 'i0'),
#                ('i0',)): Counter({('', False): 1,
#                        ('j', False): 1,
#                        ('l', False): 1,
#                        ('n', False): 1,
#                        ('t', False): 1,
#                        ('z', False): 1}),
#               (('b', 'i0', 'j'), ('i0',)): Counter({('', False): 1}),
#               (('b', 'i0', 'l'), ('i0',)): Counter({('', False): 1}),
#               (('b', 'i0', 'n'), ('i0',)): Counter({('', False): 1}),
#               (('b', 'i0', 't'), ('i0',)): Counter({('', False): 1}),
#               (('b', 'i0', 'z'), ('i0',)): Counter({('', False): 1}),
#               (('b', 'j'), ()): Counter({('t', False): 1}),
#               (('b', 'j', 't'), ()): Counter({('e0', True): 1}),
#               (('b', 'l'), ()): Counter({('a0', True): 2, ('o0', True): 1}),
#               (('b', 'l', 'a0'),
#                ('a0',)): Counter({('', False): 1, ('h', False): 1}),
#               (('b', 'l', 'o0'), ('o0',)): Counter({('g', False): 1}),
#               (('b', 'o0'),
#                ('o0',)): Counter({('', False): 1,
#                        ('j', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('s', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 2,
#                        ('ʃ', False): 1}),
#               (('b', 'o0', 'j'), ('o0',)): Counter({('', False): 1}),
#               (('b', 'o0', 'k'), ('o0',)): Counter({('', False): 1}),
#               (('b', 'o0', 'l'), ('o0',)): Counter({('', False): 1}),
#               (('b', 'o0', 's'), ('o0',)): Counter({('', False): 1}),
#               (('b', 'o0', 'z'), ('o0',)): Counter({('', False): 1}),
#               (('b', 'o0', 'ɾ'),
#                ('o0',)): Counter({('dʒ', False): 1, ('tʃ', False): 1}),
#               (('b', 'o0', 'ʃ'), ('o0',)): Counter({('', False): 1}),
#               (('b', 'u0'),
#                ('u0',)): Counter({('l', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 1}),
#               (('b', 'u0', 'l'), ('u0',)): Counter({('', False): 1}),
#               (('b', 'u0', 'z'), ('u0',)): Counter({('', False): 1}),
#               (('b', 'u0', 'ɾ'), ('u0',)): Counter({('s', False): 1}),
#               (('b', 'ɯ0'),
#                ('ɯ0',)): Counter({('z', False): 1, ('ɾ', False): 1}),
#               (('b', 'ɯ0', 'z'), ('ɯ0',)): Counter({('', False): 1}),
#               (('b', 'ɯ0', 'ɾ'), ('ɯ0',)): Counter({('', False): 1}),
#               (('b', 'ɾ'), ()): Counter({('a0', True): 1, ('o0', True): 3}),
#               (('b', 'ɾ', 'a0'), ('a0',)): Counter({('d', False): 1}),
#               (('b', 'ɾ', 'o0'),
#                ('o0',)): Counter({('n', False): 2, ('ʃ', False): 1}),
#               (('d',),
#                ()): Counter({('a0', True): 8,
#                        ('aː0', True): 1,
#                        ('e0', True): 12,
#                        ('i0', True): 11,
#                        ('o0', True): 6,
#                        ('u0', True): 5,
#                        ('y0', True): 5,
#                        ('œ0', True): 2,
#                        ('ɯ0', True): 4,
#                        ('ɾ', False): 1}),
#               (('d', 'a0'),
#                ('a0',)): Counter({('g', False): 1,
#                        ('j', False): 2,
#                        ('l', False): 1,
#                        ('n', False): 2,
#                        ('ɾ', False): 2}),
#               (('d', 'a0', 'g'), ('a0',)): Counter({('', False): 1}),
#               (('d', 'a0', 'j'),
#                ('a0',)): Counter({('', False): 1, ('s', False): 1}),
#               (('d', 'a0', 'l'), ('a0',)): Counter({('', False): 1}),
#               (('d', 'a0', 'n'),
#                ('a0',)): Counter({('', False): 2, ('s', False): 1}),
#               (('d', 'a0', 'ɾ'),
#                ('a0',)): Counter({('', False): 1, ('p', False): 1}),
#               (('d', 'aː0'), ('aː0',)): Counter({('', False): 1}),
#               (('d', 'e0'),
#                ('e0',)): Counter({('j', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('m', False): 1,
#                        ('n', False): 2,
#                        ('p', False): 1,
#                        ('s', False): 1,
#                        ('v', False): 1,
#                        ('ɾ', False): 3}),
#               (('d', 'e0', 'j'), ('e0',)): Counter({('', False): 1}),
#               (('d', 'e0', 'k'), ('e0',)): Counter({('', False): 1}),
#               (('d', 'e0', 'l'), ('e0',)): Counter({('', False): 1}),
#               (('d', 'e0', 'm'), ('e0',)): Counter({('', False): 1}),
#               (('d', 'e0', 'n'),
#                ('e0',)): Counter({('', False): 2, ('k', False): 1}),
#               (('d', 'e0', 'p'), ('e0',)): Counter({('', False): 1}),
#               (('d', 'e0', 's'), ('e0',)): Counter({('', False): 1}),
#               (('d', 'e0', 'v'), ('e0',)): Counter({('', False): 1}),
#               (('d', 'e0', 'ɾ'),
#                ('e0',)): Counter({('', False): 1,
#                        ('s', False): 1,
#                        ('t', False): 1}),
#               (('d', 'i0'),
#                ('i0',)): Counter({('', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('n', False): 2,
#                        ('p', False): 1,
#                        ('s', False): 2,
#                        ('z', False): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('d', 'i0', 'k'), ('i0',)): Counter({('', False): 1}),
#               (('d', 'i0', 'l'), ('i0',)): Counter({('', False): 1}),
#               (('d', 'i0', 'n'),
#                ('i0',)): Counter({('', False): 1, ('tʃ', False): 1}),
#               (('d', 'i0', 'p'), ('i0',)): Counter({('', False): 1}),
#               (('d', 'i0', 's'),
#                ('i0',)): Counter({('', False): 1, ('k', False): 1}),
#               (('d', 'i0', 'z'), ('i0',)): Counter({('', False): 1}),
#               (('d', 'i0', 'ɾ'), ('i0',)): Counter({('', False): 1}),
#               (('d', 'i0', 'ʃ'), ('i0',)): Counter({('', False): 1}),
#               (('d', 'o0'),
#                ('o0',)): Counter({('', False): 1,
#                        ('m', False): 1,
#                        ('n', False): 1,
#                        ('s', False): 2,
#                        ('ɾ', False): 1}),
#               (('d', 'o0', 'm'), ('o0',)): Counter({('', False): 1}),
#               (('d', 'o0', 'n'), ('o0',)): Counter({('', False): 1}),
#               (('d', 'o0', 's'),
#                ('o0',)): Counter({('', False): 1, ('t', False): 1}),
#               (('d', 'o0', 'ɾ'), ('o0',)): Counter({('t', False): 1}),
#               (('d', 'u0'),
#                ('u0',)): Counter({('', False): 1,
#                        ('l', False): 1,
#                        ('n', False): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('d', 'u0', 'l'), ('u0',)): Counter({('', False): 1}),
#               (('d', 'u0', 'n'), ('u0',)): Counter({('', False): 1}),
#               (('d', 'u0', 'ɾ'), ('u0',)): Counter({('', False): 1}),
#               (('d', 'u0', 'ʃ'), ('u0',)): Counter({('', False): 1}),
#               (('d', 'y0'),
#                ('y0',)): Counter({('', False): 1,
#                        ('n', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('d', 'y0', 'n'), ('y0',)): Counter({('', False): 1}),
#               (('d', 'y0', 'z'), ('y0',)): Counter({('', False): 1}),
#               (('d', 'y0', 'ɾ'), ('y0',)): Counter({('', False): 1}),
#               (('d', 'y0', 'ʃ'), ('y0',)): Counter({('', False): 1}),
#               (('d', 'œ0'),
#                ('œ0',)): Counter({('n', False): 1, ('ɾ', False): 1}),
#               (('d', 'œ0', 'n'), ('œ0',)): Counter({('', False): 1}),
#               (('d', 'œ0', 'ɾ'), ('œ0',)): Counter({('t', False): 1}),
#               (('d', 'ɯ0'),
#                ('ɯ0',)): Counter({('', False): 1,
#                        ('j', False): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('d', 'ɯ0', 'j'), ('ɯ0',)): Counter({('', False): 1}),
#               (('d', 'ɯ0', 'ɾ'), ('ɯ0',)): Counter({('', False): 1}),
#               (('d', 'ɯ0', 'ʃ'), ('ɯ0',)): Counter({('', False): 1}),
#               (('d', 'ɾ'), ()): Counter({('a0', True): 1}),
#               (('d', 'ɾ', 'a0'), ('a0',)): Counter({('m', False): 1}),
#               (('dʒ',),
#                ()): Counter({('a0', True): 5,
#                        ('aː0', True): 1,
#                        ('e0', True): 3,
#                        ('i0', True): 5,
#                        ('l', False): 1,
#                        ('o0', True): 4,
#                        ('u0', True): 2,
#                        ('y0', True): 2}),
#               (('dʒ', 'a0'),
#                ('a0',)): Counter({('', False): 1,
#                        ('m', False): 1,
#                        ('n', False): 1,
#                        ('s', False): 1,
#                        ('ʃ', False): 1}),
#               (('dʒ', 'a0', 'm'), ('a0',)): Counter({('', False): 1}),
#               (('dʒ', 'a0', 'n'), ('a0',)): Counter({('', False): 1}),
#               (('dʒ', 'a0', 's'), ('a0',)): Counter({('', False): 1}),
#               (('dʒ', 'a0', 'ʃ'), ('a0',)): Counter({('', False): 1}),
#               (('dʒ', 'aː0'), ('aː0',)): Counter({('', False): 1}),
#               (('dʒ', 'e0'),
#                ('e0',)): Counter({('m', False): 1,
#                        ('n', False): 1,
#                        ('p', False): 1}),
#               (('dʒ', 'e0', 'm'), ('e0',)): Counter({('', False): 1}),
#               (('dʒ', 'e0', 'n'), ('e0',)): Counter({('k', False): 1}),
#               (('dʒ', 'e0', 'p'), ('e0',)): Counter({('', False): 1}),
#               (('dʒ', 'i0'),
#                ('i0',)): Counter({('', False): 1,
#                        ('l', False): 1,
#                        ('n', False): 2,
#                        ('t', False): 1}),
#               (('dʒ', 'i0', 'l'), ('i0',)): Counter({('t', False): 1}),
#               (('dʒ', 'i0', 'n'),
#                ('i0',)): Counter({('', False): 1, ('s', False): 1}),
#               (('dʒ', 'i0', 't'), ('i0',)): Counter({('j', False): 1}),
#               (('dʒ', 'l'), ()): Counter({('u0', True): 1}),
#               (('dʒ', 'l', 'u0'), ('u0',)): Counter({('b', False): 1}),
#               (('dʒ', 'o0'),
#                ('o0',)): Counter({('', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('m', False): 1}),
#               (('dʒ', 'o0', 'k'), ('o0',)): Counter({('', False): 1}),
#               (('dʒ', 'o0', 'l'), ('o0',)): Counter({('', False): 1}),
#               (('dʒ', 'o0', 'm'), ('o0',)): Counter({('', False): 1}),
#               (('dʒ', 'u0'),
#                ('u0',)): Counter({('k', False): 1, ('p', False): 1}),
#               (('dʒ', 'u0', 'k'), ('u0',)): Counter({('', False): 1}),
#               (('dʒ', 'u0', 'p'), ('u0',)): Counter({('', False): 1}),
#               (('dʒ', 'y0'),
#                ('y0',)): Counter({('', False): 1, ('ɾ', False): 1}),
#               (('dʒ', 'y0', 'ɾ'), ('y0',)): Counter({('', False): 1}),
#               (('e0',),
#                ('e0',)): Counter({('', False): 1,
#                        ('h', False): 1,
#                        ('j', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('m', False): 1,
#                        ('n', False): 1,
#                        ('s', False): 1,
#                        ('t', False): 1,
#                        ('v', False): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('e0', 'dʒ', 'm'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'f', 'j'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'h'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'j'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'j', 'h'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'k'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'k', 's'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'l'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'l', 'tʃ'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'm'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'm', 't'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'n'), ('e0',)): Counter({('g', False): 1}),
#               (('e0', 'n', 'dʒ'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'n', 'f'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'n', 'g'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'n', 'k'), ('e0',)): Counter({('', False): 3}),
#               (('e0', 'n', 's'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'n', 't'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'n', 'tʃ'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 's'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 's', 'h'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 's', 't'), ('e0',)): Counter({('', False): 3}),
#               (('e0', 't'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'v'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'v', 'k'), ('e0',)): Counter({('', False): 2}),
#               (('e0', 'ɾ'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'ɾ', 'k'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'ɾ', 'm'), ('e0',)): Counter({('', False): 1}),
#               (('e0', 'ɾ', 's'), ('e0',)): Counter({('', False): 2}),
#               (('e0', 'ɾ', 't'), ('e0',)): Counter({('', False): 4}),
#               (('e0', 'ʃ'), ('e0',)): Counter({('', False): 1}),
#               (('f',),
#                ()): Counter({('a0', True): 4,
#                        ('e0', True): 4,
#                        ('i0', True): 4,
#                        ('l', False): 1,
#                        ('o0', True): 3,
#                        ('u0', True): 1,
#                        ('ɾ', False): 1}),
#               (('f', 'a0'),
#                ('a0',)): Counter({('k', False): 1,
#                        ('s', False): 1,
#                        ('ɾ', False): 2}),
#               (('f', 'a0', 'k'), ('a0',)): Counter({('s', False): 1}),
#               (('f', 'a0', 's'), ('a0',)): Counter({('t', False): 1}),
#               (('f', 'a0', 'ɾ'),
#                ('a0',)): Counter({('k', False): 1, ('z', False): 1}),
#               (('f', 'e0'),
#                ('e0',)): Counter({('', False): 1,
#                        ('l', False): 1,
#                        ('n', False): 1,
#                        ('ɾ', False): 1}),
#               (('f', 'e0', 'l'), ('e0',)): Counter({('tʃ', False): 1}),
#               (('f', 'e0', 'n'), ('e0',)): Counter({('', False): 1}),
#               (('f', 'e0', 'ɾ'), ('e0',)): Counter({('t', False): 1}),
#               (('f', 'i0'),
#                ('i0',)): Counter({('', False): 1,
#                        ('l', False): 2,
#                        ('t', False): 1}),
#               (('f', 'i0', 'l'),
#                ('i0',)): Counter({('', False): 1, ('m', False): 1}),
#               (('f', 'i0', 't'), ('i0',)): Counter({('', False): 1}),
#               (('f', 'l'), ()): Counter({('a0', True): 1}),
#               (('f', 'l', 'a0'), ('a0',)): Counter({('ʃ', False): 1}),
#               (('f', 'o0'),
#                ('o0',)): Counter({('n', False): 1, ('ɾ', False): 2}),
#               (('f', 'o0', 'n'), ('o0',)): Counter({('', False): 1}),
#               (('f', 'o0', 'ɾ'),
#                ('o0',)): Counter({('', False): 1, ('m', False): 1}),
#               (('f', 'u0'), ('u0',)): Counter({('lː', False): 1}),
#               (('f', 'u0', 'lː'), ('u0',)): Counter({('', False): 1}),
#               (('f', 'ɾ'), ()): Counter({('o0', True): 1}),
#               (('f', 'ɾ', 'o0'), ('o0',)): Counter({('m', False): 1}),
#               (('g',),
#                ()): Counter({('a0', True): 4,
#                        ('e0', True): 8,
#                        ('i0', True): 2,
#                        ('o0', True): 4,
#                        ('s', False): 1,
#                        ('u0', True): 2,
#                        ('y0', True): 4,
#                        ('œ0', True): 6,
#                        ('ɾ', False): 4}),
#               (('g', 'a0'),
#                ('a0',)): Counter({('j', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 2}),
#               (('g', 'a0', 'j'), ('a0',)): Counter({('', False): 1}),
#               (('g', 'a0', 'z'), ('a0',)): Counter({('', False): 1}),
#               (('g', 'a0', 'ɾ'),
#                ('a0',)): Counter({('d', False): 1, ('k', False): 1}),
#               (('g', 'e0'),
#                ('e0',)): Counter({('', False): 1,
#                        ('dʒ', False): 1,
#                        ('l', False): 1,
#                        ('n', False): 3,
#                        ('tʃ', False): 1,
#                        ('z', False): 1}),
#               (('g', 'e0', 'dʒ'), ('e0',)): Counter({('', False): 1}),
#               (('g', 'e0', 'l'), ('e0',)): Counter({('', False): 1}),
#               (('g', 'e0', 'n'),
#                ('e0',)): Counter({('', False): 1,
#                        ('dʒ', False): 1,
#                        ('tʃ', False): 1}),
#               (('g', 'e0', 'tʃ'), ('e0',)): Counter({('', False): 1}),
#               (('g', 'e0', 'z'), ('e0',)): Counter({('', False): 1}),
#               (('g', 'i0'),
#                ('i0',)): Counter({('f', False): 1, ('t', False): 1}),
#               (('g', 'i0', 'f'), ('i0',)): Counter({('', False): 1}),
#               (('g', 'i0', 't'), ('i0',)): Counter({('', False): 1}),
#               (('g', 'o0'),
#                ('o0',)): Counter({('', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('z', False): 1}),
#               (('g', 'o0', 'k'), ('o0',)): Counter({('', False): 1}),
#               (('g', 'o0', 'l'), ('o0',)): Counter({('', False): 1}),
#               (('g', 'o0', 'z'), ('o0',)): Counter({('', False): 1}),
#               (('g', 's'), ()): Counter({('j', False): 1}),
#               (('g', 's', 'j'), ()): Counter({('i0', True): 1}),
#               (('g', 'u0'),
#                ('u0',)): Counter({('n', False): 1, ('t', False): 1}),
#               (('g', 'u0', 'n'), ('u0',)): Counter({('', False): 1}),
#               (('g', 'u0', 't'), ('u0',)): Counter({('', False): 1}),
#               (('g', 'y0'),
#                ('y0',)): Counter({('l', False): 1,
#                        ('tʃ', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 1}),
#               (('g', 'y0', 'l'), ('y0',)): Counter({('', False): 1}),
#               (('g', 'y0', 'tʃ'), ('y0',)): Counter({('', False): 1}),
#               (('g', 'y0', 'z'), ('y0',)): Counter({('', False): 1}),
#               (('g', 'y0', 'ɾ'), ('y0',)): Counter({('', False): 1}),
#               (('g', 'œ0'),
#                ('œ0',)): Counter({('', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('tʃ', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 1}),
#               (('g', 'œ0', 'k'), ('œ0',)): Counter({('', False): 1}),
#               (('g', 'œ0', 'l'), ('œ0',)): Counter({('', False): 1}),
#               (('g', 'œ0', 'tʃ'), ('œ0',)): Counter({('', False): 1}),
#               (('g', 'œ0', 'z'), ('œ0',)): Counter({('', False): 1}),
#               (('g', 'œ0', 'ɾ'), ('œ0',)): Counter({('', False): 1}),
#               (('g', 'ɾ'),
#                ()): Counter({('a0', True): 1,
#                        ('i0', True): 2,
#                        ('u0', True): 1}),
#               (('g', 'ɾ', 'a0'), ('a0',)): Counter({('m', False): 1}),
#               (('g', 'ɾ', 'i0'),
#                ('i0',)): Counter({('', False): 1, ('p', False): 1}),
#               (('g', 'ɾ', 'u0'), ('u0',)): Counter({('p', False): 1}),
#               (('h',),
#                ()): Counter({('a0', True): 20,
#                        ('e0', True): 4,
#                        ('i0', True): 4,
#                        ('o0', True): 5,
#                        ('y0', True): 1,
#                        ('ɯ0', True): 2}),
#               (('h', 'a0'),
#                ('a0',)): Counter({('', False): 1,
#                        ('d', False): 1,
#                        ('j', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 3,
#                        ('m', False): 2,
#                        ('n', False): 1,
#                        ('p', False): 1,
#                        ('pː', False): 1,
#                        ('s', False): 1,
#                        ('t', False): 1,
#                        ('tʃ', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 4}),
#               (('h', 'a0', 'd'), ('a0',)): Counter({('', False): 1}),
#               (('h', 'a0', 'j'), ('a0',)): Counter({('', False): 1}),
#               (('h', 'a0', 'k'), ('a0',)): Counter({('', False): 1}),
#               (('h', 'a0', 'l'),
#                ('a0',)): Counter({('', False): 1,
#                        ('k', False): 1,
#                        ('t', False): 1}),
#               (('h', 'a0', 'm'),
#                ('a0',)): Counter({('', False): 1, ('d', False): 1}),
#               (('h', 'a0', 'n'), ('a0',)): Counter({('', False): 1}),
#               (('h', 'a0', 'p'), ('a0',)): Counter({('', False): 1}),
#               (('h', 'a0', 'pː'), ('a0',)): Counter({('j', False): 1}),
#               (('h', 'a0', 's'), ('a0',)): Counter({('', False): 1}),
#               (('h', 'a0', 't'), ('a0',)): Counter({('', False): 1}),
#               (('h', 'a0', 'tʃ'), ('a0',)): Counter({('', False): 1}),
#               (('h', 'a0', 'z'), ('a0',)): Counter({('', False): 1}),
#               (('h', 'a0', 'ɾ'),
#                ('a0',)): Counter({('d', False): 1,
#                        ('f', False): 1,
#                        ('p', False): 1,
#                        ('tʃ', False): 1}),
#               (('h', 'e0'),
#                ('e0',)): Counter({('', False): 1,
#                        ('j', False): 1,
#                        ('p', False): 1,
#                        ('tʃ', False): 1}),
#               (('h', 'e0', 'j'), ('e0',)): Counter({('', False): 1}),
#               (('h', 'e0', 'p'), ('e0',)): Counter({('', False): 1}),
#               (('h', 'e0', 'tʃ'), ('e0',)): Counter({('', False): 1}),
#               (('h', 'i0'),
#                ('i0',)): Counter({('dʒ', False): 1,
#                        ('n', False): 1,
#                        ('s', False): 1,
#                        ('t', False): 1}),
#               (('h', 'i0', 'dʒ'), ('i0',)): Counter({('', False): 1}),
#               (('h', 'i0', 'n'), ('i0',)): Counter({('t', False): 1}),
#               (('h', 'i0', 's'), ('i0',)): Counter({('', False): 1}),
#               (('h', 'i0', 't'), ('i0',)): Counter({('', False): 1}),
#               (('h', 'o0'),
#                ('o0',)): Counter({('p', False): 1,
#                        ('s', False): 2,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('h', 'o0', 'p'), ('o0',)): Counter({('', False): 1}),
#               (('h', 'o0', 's'),
#                ('o0',)): Counter({('', False): 1, ('t', False): 1}),
#               (('h', 'o0', 'ɾ'), ('o0',)): Counter({('', False): 1}),
#               (('h', 'o0', 'ʃ'), ('o0',)): Counter({('', False): 1}),
#               (('h', 'y0'), ('y0',)): Counter({('ɾ', False): 1}),
#               (('h', 'y0', 'ɾ'), ('y0',)): Counter({('', False): 1}),
#               (('h', 'ɯ0'),
#                ('ɯ0',)): Counter({('z', False): 1, ('ɾ', False): 1}),
#               (('h', 'ɯ0', 'z'), ('ɯ0',)): Counter({('', False): 1}),
#               (('h', 'ɯ0', 'ɾ'), ('ɯ0',)): Counter({('s', False): 1}),
#               (('i0',),
#                ('i0',)): Counter({('', False): 1,
#                        ('b', False): 1,
#                        ('dʒ', False): 1,
#                        ('hː', False): 1,
#                        ('l', False): 1,
#                        ('m', False): 1,
#                        ('n', False): 1,
#                        ('p', False): 1,
#                        ('s', False): 2,
#                        ('t', False): 1,
#                        ('tʃ', False): 1,
#                        ('z', False): 1,
#                        ('ʃ', False): 1}),
#               (('i0', 'b'), ('i0',)): Counter({('n', False): 1}),
#               (('i0', 'b', 'n'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'dʒ'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'dʒ', 'k'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'f', 't'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'hː'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'l'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'l', 'm'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'l', 't'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'm'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'n'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'n', 'k'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'n', 's'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'n', 't'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'n', 'tʃ'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'p'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 's'),
#                ('i0',)): Counter({('', False): 1, ('t', False): 1}),
#               (('i0', 's', 'k'), ('i0',)): Counter({('', False): 2}),
#               (('i0', 's', 't'), ('i0',)): Counter({('', False): 2}),
#               (('i0', 't'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 't', 'j'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 't', 'm'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'tʃ'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'z'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'ɾ', 'f'), ('i0',)): Counter({('', False): 1}),
#               (('i0', 'ɾ', 'k'), ('i0',)): Counter({('', False): 2}),
#               (('i0', 'ʃ'), ('i0',)): Counter({('', False): 1}),
#               (('j',),
#                ()): Counter({('a0', True): 10,
#                        ('aː0', True): 1,
#                        ('e0', True): 6,
#                        ('i0', True): 2,
#                        ('l', False): 2,
#                        ('o0', True): 2,
#                        ('u0', True): 4,
#                        ('y0', True): 3,
#                        ('œ0', True): 1,
#                        ('ɯ0', True): 1}),
#               (('j', 'a0'),
#                ('a0',)): Counter({('d', False): 1,
#                        ('g', False): 1,
#                        ('j', False): 1,
#                        ('n', False): 1,
#                        ('p', False): 1,
#                        ('s', False): 1,
#                        ('t', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('j', 'a0', 'd'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'a0', 'g'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'a0', 'j'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'a0', 'n'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'a0', 'p'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'a0', 's'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'a0', 't'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'a0', 'z'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'a0', 'ɾ'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'a0', 'ʃ'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'aː0'), ('aː0',)): Counter({('', False): 1}),
#               (('j', 'e0'),
#                ('e0',)): Counter({('', False): 1,
#                        ('d', False): 1,
#                        ('l', False): 1,
#                        ('m', False): 1,
#                        ('n', False): 1,
#                        ('ɾ', False): 1}),
#               (('j', 'e0', 'd'), ('e0',)): Counter({('', False): 1}),
#               (('j', 'e0', 'l'), ('e0',)): Counter({('', False): 1}),
#               (('j', 'e0', 'm'), ('e0',)): Counter({('', False): 1}),
#               (('j', 'e0', 'n'), ('e0',)): Counter({('', False): 1}),
#               (('j', 'e0', 'ɾ'), ('e0',)): Counter({('', False): 1}),
#               (('j', 'i0'),
#                ('i0',)): Counter({('', False): 1, ('l', False): 1}),
#               (('j', 'i0', 'h'), ('i0',)): Counter({('', False): 1}),
#               (('j', 'i0', 'l'), ('i0',)): Counter({('', False): 1}),
#               (('j', 'l'), ()): Counter({('a0', True): 1, ('e0', True): 1}),
#               (('j', 'l', 'a0'), ('a0',)): Counter({('', False): 1}),
#               (('j', 'l', 'e0'), ('e0',)): Counter({('', False): 1}),
#               (('j', 'o0'),
#                ('o0',)): Counter({('', False): 1, ('l', False): 1}),
#               (('j', 'o0', 'l'), ('o0',)): Counter({('', False): 1}),
#               (('j', 's', 't'), ()): Counter({('e0', True): 1}),
#               (('j', 't', 'e0'), ('e0',)): Counter({('s', False): 1}),
#               (('j', 'u0'),
#                ('u0',)): Counter({('', False): 1,
#                        ('h', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 1}),
#               (('j', 'u0', 'h'), ('u0',)): Counter({('', False): 1}),
#               (('j', 'u0', 'z'), ('u0',)): Counter({('', False): 1}),
#               (('j', 'u0', 'ɾ'), ('u0',)): Counter({('t', False): 1}),
#               (('j', 'y0'),
#                ('y0',)): Counter({('k', False): 1,
#                        ('n', False): 1,
#                        ('z', False): 1}),
#               (('j', 'y0', 'k'), ('y0',)): Counter({('', False): 1}),
#               (('j', 'y0', 'n'), ('y0',)): Counter({('', False): 1}),
#               (('j', 'y0', 'z'), ('y0',)): Counter({('', False): 1}),
#               (('j', 'œ0'), ('œ0',)): Counter({('n', False): 1}),
#               (('j', 'œ0', 'n'), ('œ0',)): Counter({('', False): 1}),
#               (('j', 'ɯ0'), ('ɯ0',)): Counter({('', False): 1}),
#               (('k',),
#                ()): Counter({('a0', True): 18,
#                        ('e0', True): 8,
#                        ('i0', True): 9,
#                        ('l', False): 2,
#                        ('o0', True): 10,
#                        ('u0', True): 8,
#                        ('y0', True): 5,
#                        ('œ0', True): 5,
#                        ('ɯ0', True): 6,
#                        ('ɾ', False): 3,
#                        ('ʲ', False): 2}),
#               (('k', 'a0'),
#                ('a0',)): Counter({('', False): 1,
#                        ('dʒ', False): 1,
#                        ('h', False): 1,
#                        ('l', False): 4,
#                        ('m', False): 1,
#                        ('n', False): 1,
#                        ('p', False): 1,
#                        ('s', False): 2,
#                        ('t', False): 1,
#                        ('tʃ', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 2,
#                        ('ʃ', False): 1}),
#               (('k', 'a0', 'dʒ'), ('a0',)): Counter({('', False): 1}),
#               (('k', 'a0', 'h'), ('a0',)): Counter({('', False): 1}),
#               (('k', 'a0', 'l'),
#                ('a0',)): Counter({('', False): 1,
#                        ('b', False): 1,
#                        ('k', False): 1,
#                        ('p', False): 1}),
#               (('k', 'a0', 'm'), ('a0',)): Counter({('p', False): 1}),
#               (('k', 'a0', 'n'), ('a0',)): Counter({('', False): 1}),
#               (('k', 'a0', 'p'), ('a0',)): Counter({('', False): 1}),
#               (('k', 'a0', 's'),
#                ('a0',)): Counter({('', False): 1, ('t', False): 1}),
#               (('k', 'a0', 't'), ('a0',)): Counter({('', False): 1}),
#               (('k', 'a0', 'tʃ'), ('a0',)): Counter({('', False): 1}),
#               (('k', 'a0', 'z'), ('a0',)): Counter({('', False): 1}),
#               (('k', 'a0', 'ɾ'),
#                ('a0',)): Counter({('', False): 1, ('t', False): 1}),
#               (('k', 'a0', 'ʃ'), ('a0',)): Counter({('', False): 1}),
#               (('k', 'e0'),
#                ('e0',)): Counter({('k', False): 1,
#                        ('l', False): 1,
#                        ('m', False): 1,
#                        ('n', False): 2,
#                        ('s', False): 1,
#                        ('t', False): 1,
#                        ('z', False): 1}),
#               (('k', 'e0', 'k'), ('e0',)): Counter({('', False): 1}),
#               (('k', 'e0', 'l'), ('e0',)): Counter({('', False): 1}),
#               (('k', 'e0', 'm'), ('e0',)): Counter({('', False): 1}),
#               (('k', 'e0', 'n'),
#                ('e0',)): Counter({('', False): 1, ('t', False): 1}),
#               (('k', 'e0', 's'), ('e0',)): Counter({('', False): 1}),
#               (('k', 'e0', 't'), ('e0',)): Counter({('', False): 1}),
#               (('k', 'e0', 'z'), ('e0',)): Counter({('', False): 1}),
#               (('k', 'i0'),
#                ('i0',)): Counter({('l', False): 1,
#                        ('m', False): 1,
#                        ('n', False): 1,
#                        ('p', False): 1,
#                        ('s', False): 2,
#                        ('z', False): 1,
#                        ('ɾ', False): 2}),
#               (('k', 'i0', 'l'), ('i0',)): Counter({('', False): 1}),
#               (('k', 'i0', 'm'), ('i0',)): Counter({('', False): 1}),
#               (('k', 'i0', 'n'), ('i0',)): Counter({('', False): 1}),
#               (('k', 'i0', 'p'), ('i0',)): Counter({('', False): 1}),
#               (('k', 'i0', 's'),
#                ('i0',)): Counter({('', False): 1, ('t', False): 1}),
#               (('k', 'i0', 'z'), ('i0',)): Counter({('', False): 1}),
#               (('k', 'i0', 'ɾ'),
#                ('i0',)): Counter({('', False): 1, ('k', False): 1}),
#               (('k', 'l'), ()): Counter({('u0', True): 1, ('y0', True): 1}),
#               (('k', 'l', 'u0'), ('u0',)): Counter({('p', False): 1}),
#               (('k', 'l', 'y0'), ('y0',)): Counter({('p', False): 1}),
#               (('k', 'o0'),
#                ('o0',)): Counter({('', False): 1,
#                        ('d', False): 1,
#                        ('j', False): 1,
#                        ('l', False): 1,
#                        ('p', False): 1,
#                        ('t', False): 1,
#                        ('tʃ', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('k', 'o0', 'd'), ('o0',)): Counter({('', False): 1}),
#               (('k', 'o0', 'j'), ('o0',)): Counter({('', False): 1}),
#               (('k', 'o0', 'l'), ('o0',)): Counter({('', False): 1}),
#               (('k', 'o0', 'p'), ('o0',)): Counter({('', False): 1}),
#               (('k', 'o0', 't'), ('o0',)): Counter({('', False): 1}),
#               (('k', 'o0', 'tʃ'), ('o0',)): Counter({('', False): 1}),
#               (('k', 'o0', 'z'), ('o0',)): Counter({('', False): 1}),
#               (('k', 'o0', 'ɾ'), ('o0',)): Counter({('', False): 2}),
#               (('k', 'o0', 'ʃ'), ('o0',)): Counter({('', False): 1}),
#               (('k', 'u0'),
#                ('u0',)): Counter({('', False): 1,
#                        ('l', False): 1,
#                        ('m', False): 1,
#                        ('s', False): 1,
#                        ('ɾ', False): 3,
#                        ('ʃ', False): 1}),
#               (('k', 'u0', 'l'), ('u0',)): Counter({('', False): 1}),
#               (('k', 'u0', 'm'), ('u0',)): Counter({('', False): 1}),
#               (('k', 'u0', 's'), ('u0',)): Counter({('', False): 1}),
#               (('k', 'u0', 'ɾ'),
#                ('u0',)): Counter({('', False): 1,
#                        ('d', False): 1,
#                        ('t', False): 1}),
#               (('k', 'u0', 'ʃ'), ('u0',)): Counter({('', False): 1}),
#               (('k', 'y0'),
#                ('y0',)): Counter({('l', False): 1,
#                        ('n', False): 1,
#                        ('p', False): 1,
#                        ('ɾ', False): 2}),
#               (('k', 'y0', 'l'), ('y0',)): Counter({('', False): 1}),
#               (('k', 'y0', 'n'), ('y0',)): Counter({('', False): 1}),
#               (('k', 'y0', 'p'), ('y0',)): Counter({('', False): 1}),
#               (('k', 'y0', 'ɾ'),
#                ('y0',)): Counter({('k', False): 1, ('t', False): 1}),
#               (('k', 'œ0'),
#                ('œ0',)): Counter({('j', False): 1,
#                        ('k', False): 1,
#                        ('p', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 1}),
#               (('k', 'œ0', 'j'), ('œ0',)): Counter({('', False): 1}),
#               (('k', 'œ0', 'k'), ('œ0',)): Counter({('', False): 1}),
#               (('k', 'œ0', 'p'), ('œ0',)): Counter({('', False): 1}),
#               (('k', 'œ0', 'z'), ('œ0',)): Counter({('', False): 1}),
#               (('k', 'œ0', 'ɾ'), ('œ0',)): Counter({('', False): 1}),
#               (('k', 'ɯ0'),
#                ('ɯ0',)): Counter({('l', False): 1,
#                        ('t', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 2,
#                        ('ʃ', False): 1}),
#               (('k', 'ɯ0', 'l'), ('ɯ0',)): Counter({('', False): 1}),
#               (('k', 'ɯ0', 't'), ('ɯ0',)): Counter({('', False): 1}),
#               (('k', 'ɯ0', 'z'), ('ɯ0',)): Counter({('', False): 1}),
#               (('k', 'ɯ0', 'ɾ'),
#                ('ɯ0',)): Counter({('', False): 1, ('k', False): 1}),
#               (('k', 'ɯ0', 'ʃ'), ('ɯ0',)): Counter({('', False): 1}),
#               (('k', 'ɾ'),
#                ()): Counter({('a0', True): 1,
#                        ('e0', True): 1,
#                        ('i0', True): 1}),
#               (('k', 'ɾ', 'a0'), ('a0',)): Counter({('l', False): 1}),
#               (('k', 'ɾ', 'e0'), ('e0',)): Counter({('m', False): 1}),
#               (('k', 'ɾ', 'i0'), ('i0',)): Counter({('z', False): 1}),
#               (('k', 'ʲ'), ()): Counter({('a0', True): 2}),
#               (('k', 'ʲ', 'a0'),
#                ('a0',)): Counter({('h', False): 1, ('ɾ', False): 1}),
#               (('l',),
#                ()): Counter({('a0', True): 4,
#                        ('e0', True): 4,
#                        ('i0', True): 4,
#                        ('o0', True): 2,
#                        ('u0', True): 2,
#                        ('y0', True): 4,
#                        ('ɯ0', True): 2}),
#               (('l', 'a0'),
#                ('a0',)): Counter({('', False): 1,
#                        ('f', False): 1,
#                        ('n', False): 1,
#                        ('ɾ', False): 1}),
#               (('l', 'a0', 'f'), ('a0',)): Counter({('', False): 1}),
#               (('l', 'a0', 'h'), ('a0',)): Counter({('', False): 1}),
#               (('l', 'a0', 'j'), ('a0',)): Counter({('', False): 1}),
#               (('l', 'a0', 'k'), ('a0',)): Counter({('', False): 1}),
#               (('l', 'a0', 'n'), ('a0',)): Counter({('', False): 2}),
#               (('l', 'a0', 'ɾ'), ('a0',)): Counter({('', False): 1}),
#               (('l', 'a0', 'ʃ'), ('a0',)): Counter({('', False): 1}),
#               (('l', 'e0'),
#                ('e0',)): Counter({('', False): 1,
#                        ('n', False): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('l', 'e0', 'n'), ('e0',)): Counter({('f', False): 1}),
#               (('l', 'e0', 'ɾ'), ('e0',)): Counter({('', False): 1}),
#               (('l', 'e0', 'ʃ'), ('e0',)): Counter({('', False): 1}),
#               (('l', 'i0'),
# ...
#               (('dʒ', 'u0', 'n'), ('o0', 'u0')): Counter({('', False): 1}),
#               (('dʒ', 'u0', 'n'), ('u0',)): Counter({('k', False): 1}),
#               (('dʒ', 'u0', 't'), ('e0', 'u0')): Counter({('', False): 1}),
#               (('dʒ', 'u0', 't'), ('y0', 'u0')): Counter({('', False): 1}),
#               (('dʒ', 'u0', 'z'), ('u0', 'u0')): Counter({('', False): 1}),
#               (('dʒ', 'y0'),
#                ('y0',)): Counter({('m', False): 1, ('z', False): 1}),
#               (('dʒ', 'y0', 'k'), ('œ0', 'y0')): Counter({('', False): 1}),
#               (('dʒ', 'y0', 'm'), ('y0',)): Counter({('l', False): 1}),
#               (('dʒ', 'y0', 'm'), ('y0', 'y0')): Counter({('', False): 1}),
#               (('dʒ', 'y0', 'n'), ('y0', 'y0')): Counter({('', False): 1}),
#               (('dʒ', 'y0', 'z'), ('y0',)): Counter({('i0', True): 1}),
#               (('dʒ', 'œ0'), ('œ0',)): Counter({('m', False): 1}),
#               (('dʒ', 'œ0', 'm'), ('œ0',)): Counter({('e0', True): 1}),
#               (('dʒ', 'ɯ0'),
#                ('ɯ0',)): Counter({('l', False): 1,
#                        ('v', False): 2,
#                        ('ɾ', False): 1}),
#               (('dʒ', 'ɯ0', 'k'), ('a0', 'ɯ0')): Counter({('', False): 1}),
#               (('dʒ', 'ɯ0', 'k'), ('ɯ0', 'ɯ0')): Counter({('', False): 1}),
#               (('dʒ', 'ɯ0', 'l'), ('ɯ0',)): Counter({('ɯ0', True): 1}),
#               (('dʒ', 'ɯ0', 'v'),
#                ('ɯ0',)): Counter({('a0', True): 1, ('ɯ0', True): 1}),
#               (('dʒ', 'ɯ0', 'ɾ'), ('ɯ0',)): Counter({('ɯ0', True): 1}),
#               (('dʒ', 'ɾ'), ()): Counter({('e0', True): 1}),
#               (('dʒ', 'ɾ', 'a0'), ('i0', 'a0')): Counter({('', False): 1}),
#               (('dʒ', 'ɾ', 'e0'), ('e0',)): Counter({('a0', True): 1}),
#               (('dʒ', 'ɾ', 'e0'), ('e0', 'e0')): Counter({('t', False): 1}),
#               (('dʒ', 'ɾ', 'e0'),
#                ('y0', 'e0')): Counter({('', False): 1, ('t', False): 1}),
#               (('dʒ', 'ɾ', 'i0'), ('e0', 'i0')): Counter({('t', False): 1}),
#               (('dʒ', 'ɾ', 'i0'), ('i0', 'i0')): Counter({('', False): 1}),
#               (('dː', 'e0', 'n'), ('i0', 'e0')): Counter({('', False): 1}),
#               (('dː', 'e0', 't'), ('i0', 'e0')): Counter({('', False): 2}),
#               (('dː', 'e0', 't'), ('y0', 'e0')): Counter({('', False): 1}),
#               (('e0',),
#                ('e0',)): Counter({('b', False): 1,
#                        ('d', False): 12,
#                        ('dʒ', False): 1,
#                        ('e0', True): 2,
#                        ('f', False): 1,
#                        ('g', False): 3,
#                        ('h', False): 1,
#                        ('i0', True): 1,
#                        ('j', False): 3,
#                        ('k', False): 16,
#                        ('l', False): 13,
#                        ('lː', False): 3,
#                        ('m', False): 7,
#                        ('n', False): 10,
#                        ('p', False): 2,
#                        ('s', False): 9,
#                        ('t', False): 25,
#                        ('tː', False): 3,
#                        ('v', False): 15,
#                        ('vː', False): 1,
#                        ('z', False): 5,
#                        ('ɾ', False): 14,
#                        ('ʃ', False): 7}),
#               (('e0', 'a0', 'm'), ('e0', 'a0')): Counter({('', False): 1}),
#               (('e0', 'a0', 'n'), ('e0', 'a0')): Counter({('', False): 1}),
#               (('e0', 'a0', 'v'), ('e0', 'a0')): Counter({('j', False): 1}),
#               (('e0', 'b'), ('e0',)): Counter({('ɾ', False): 1}),
#               (('e0', 'b', 'a0'),
#                ('e0', 'a0')): Counter({('', False): 1,
#                        ('p', False): 1,
#                        ('t', False): 1}),
#               (('e0', 'b', 'e0'),
#                ('e0', 'e0')): Counter({('', False): 3,
#                        ('b', False): 1,
#                        ('k', False): 1,
#                        ('p', False): 1}),
#               (('e0', 'b', 'i0'),
#                ('e0', 'i0')): Counter({('ɾ', False): 1, ('ʃ', False): 1}),
#               (('e0', 'b', 'l'), ('e0',)): Counter({('iː0', True): 1}),
#               (('e0', 'b', 'z'), ('e0',)): Counter({('e0', True): 2}),
#               (('e0', 'b', 'ɾ'),
#                ('e0',)): Counter({('i0', True): 1, ('u0', True): 1}),
#               (('e0', 'd'),
#                ('e0',)): Counter({('a0', True): 1,
#                        ('e0', True): 4,
#                        ('i0', True): 7}),
#               (('e0', 'd', 'a0'), ('e0', 'a0')): Counter({('', False): 4}),
#               (('e0', 'd', 'b'), ('e0',)): Counter({('i0', True): 1}),
#               (('e0', 'd', 'e0'),
#                ('e0', 'e0')): Counter({('', False): 3,
#                        ('f', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('m', False): 2,
#                        ('n', False): 3,
#                        ('t', False): 1,
#                        ('ɾ', False): 2}),
#               (('e0', 'd', 'g'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'd', 'i0'),
#                ('e0', 'i0')): Counter({('', False): 5,
#                        ('b', False): 1,
#                        ('k', False): 3,
#                        ('m', False): 3,
#                        ('n', False): 2,
#                        ('p', False): 1,
#                        ('t', False): 1,
#                        ('ɾ', False): 2}),
#               (('e0', 'd', 'j'), ('e0',)): Counter({('a0', True): 1}),
#               (('e0', 'dʒ'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'dʒ', 'a0'), ('e0', 'a0')): Counter({('z', False): 1}),
#               (('e0', 'dʒ', 'b'), ('e0',)): Counter({('u0', True): 1}),
#               (('e0', 'dʒ', 'd'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'dʒ', 'e0'),
#                ('e0', 'e0')): Counter({('', False): 4,
#                        ('n', False): 1,
#                        ('ɾ', False): 1}),
#               (('e0', 'dʒ', 'i0'),
#                ('e0', 'i0')): Counter({('', False): 1, ('p', False): 1}),
#               (('e0', 'dʒ', 'l'), ('e0',)): Counter({('i0', True): 1}),
#               (('e0', 'dʒ', 'm'), ('e0',)): Counter({('i0', True): 1}),
#               (('e0', 'dʒ', 'o0'), ('e0', 'o0')): Counter({('n', False): 1}),
#               (('e0', 'dʒ', 't'), ('e0',)): Counter({('i0', True): 1}),
#               (('e0', 'dʒ', 'ɾ'),
#                ('e0',)): Counter({('e0', True): 1, ('i0', True): 1}),
#               (('e0', 'e0'),
#                ('e0', 'e0')): Counter({('', False): 1, ('ɾ', False): 1}),
#               (('e0', 'e0', 'l'), ('e0', 'e0')): Counter({('', False): 1}),
#               (('e0', 'e0', 'n'), ('e0', 'e0')): Counter({('', False): 1}),
#               (('e0', 'e0', 'ɾ'), ('e0', 'e0')): Counter({('', False): 3}),
#               (('e0', 'f'), ('e0',)): Counter({('o0', True): 1}),
#               (('e0', 'f', 'a0'),
#                ('e0', 'a0')): Counter({('', False): 2,
#                        ('h', False): 1,
#                        ('n', False): 1,
#                        ('t', False): 1}),
#               (('e0', 'f', 'e0'),
#                ('e0', 'e0')): Counter({('', False): 1,
#                        ('k', False): 1,
#                        ('s', False): 1,
#                        ('ɾ', False): 2}),
#               (('e0', 'f', 'i0'),
#                ('e0', 'i0')): Counter({('', False): 1,
#                        ('l', False): 1,
#                        ('s', False): 1}),
#               (('e0', 'f', 'k'), ('e0',)): Counter({('a0', True): 1}),
#               (('e0', 'f', 'l'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'f', 'o0'), ('e0', 'o0')): Counter({('ɾ', False): 2}),
#               (('e0', 'f', 's'), ('e0',)): Counter({('i0', True): 3}),
#               (('e0', 'f', 't'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'f', 'ɾ'),
#                ('e0',)): Counter({('e0', True): 1, ('i0', True): 1}),
#               (('e0', 'fː', 'a0'), ('e0', 'a0')): Counter({('f', False): 1}),
#               (('e0', 'g'),
#                ('e0',)): Counter({('e0', True): 2, ('o0', True): 1}),
#               (('e0', 'g', 'e0'),
#                ('e0', 'e0')): Counter({('', False): 1,
#                        ('n', False): 1,
#                        ('ɾ', False): 2}),
#               (('e0', 'g', 'i0'), ('e0', 'i0')): Counter({('l', False): 1}),
#               (('e0', 'g', 'o0'), ('e0', 'o0')): Counter({('', False): 1}),
#               (('e0', 'h'), ('e0',)): Counter({('l', False): 1}),
#               (('e0', 'h', 'a0'), ('e0', 'a0')): Counter({('', False): 1}),
#               (('e0', 'h', 'b'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'h', 'd'), ('e0',)): Counter({('i0', True): 1}),
#               (('e0', 'h', 'dʒ'), ('e0',)): Counter({('i0', True): 1}),
#               (('e0', 'h', 'i0'),
#                ('e0', 'i0')): Counter({('n', False): 1,
#                        ('t', False): 2,
#                        ('ɾ', False): 4}),
#               (('e0', 'h', 'l'), ('e0',)): Counter({('i0', True): 1}),
#               (('e0', 'h', 'm'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'h', 'tʃ'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'h', 'ɾ'),
#                ('e0',)): Counter({('e0', True): 1, ('i0', True): 4}),
#               (('e0', 'h', 'ʃ'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'i0'), ('e0', 'i0')): Counter({('p', False): 1}),
#               (('e0', 'i0', 'n'), ('e0', 'i0')): Counter({('', False): 1}),
#               (('e0', 'i0', 'p'), ('e0', 'i0')): Counter({('', False): 1}),
#               (('e0', 'i0', 's'), ('e0', 'i0')): Counter({('', False): 1}),
#               (('e0', 'j'), ('e0',)): Counter({('l', False): 3}),
#               (('e0', 'j', 'a0'),
#                ('e0', 'a0')): Counter({('n', False): 1, ('z', False): 1}),
#               (('e0', 'j', 'd'),
#                ('e0',)): Counter({('a0', True): 1,
#                        ('e0', True): 2,
#                        ('i0', True): 4}),
#               (('e0', 'j', 'e0'),
#                ('e0', 'e0')): Counter({('', False): 3, ('t', False): 1}),
#               (('e0', 'j', 'f'), ('e0',)): Counter({('i0', True): 1}),
#               (('e0', 'j', 'i0'),
#                ('e0', 'i0')): Counter({('', False): 4,
#                        ('d', False): 1,
#                        ('f', False): 1,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('m', False): 4,
#                        ('n', False): 4,
#                        ('p', False): 1,
#                        ('t', False): 1,
#                        ('z', False): 1,
#                        ('ɾ', False): 2}),
#               (('e0', 'j', 'k'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'j', 'l'),
#                ('e0',)): Counter({('a0', True): 1,
#                        ('e0', True): 7,
#                        ('i0', True): 1,
#                        ('y0', True): 1}),
#               (('e0', 'j', 'm'), ('e0',)): Counter({('i0', True): 2}),
#               (('e0', 'j', 'n'),
#                ('e0',)): Counter({('e0', True): 2, ('i0', True): 4}),
#               (('e0', 'j', 's'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'j', 't'),
#                ('e0',)): Counter({('a0', True): 1, ('i0', True): 2}),
#               (('e0', 'j', 'v'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'j', 'z'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'j', 'ɾ'),
#                ('e0',)): Counter({('e0', True): 2, ('i0', True): 1}),
#               (('e0', 'k'),
#                ('e0',)): Counter({('e0', True): 1,
#                        ('i0', True): 4,
#                        ('l', False): 4,
#                        ('m', False): 1,
#                        ('s', False): 3,
#                        ('ɯ0', True): 1,
#                        ('ɾ', False): 1,
#                        ('ʃ', False): 1}),
#               (('e0', 'k', 'a0'),
#                ('e0', 'a0')): Counter({('', False): 1,
#                        ('n', False): 2,
#                        ('t', False): 1,
#                        ('ɾ', False): 1}),
#               (('e0', 'k', 'e0'),
#                ('e0', 'e0')): Counter({('', False): 3,
#                        ('n', False): 2,
#                        ('ɾ', False): 4}),
#               (('e0', 'k', 'i0'),
#                ('e0', 'i0')): Counter({('', False): 7,
#                        ('k', False): 1,
#                        ('l', False): 3,
#                        ('m', False): 3,
#                        ('n', False): 4,
#                        ('p', False): 3,
#                        ('t', False): 1,
#                        ('z', False): 1}),
#               (('e0', 'k', 'l'),
#                ('e0',)): Counter({('a0', True): 1,
#                        ('e0', True): 6,
#                        ('i0', True): 3}),
#               (('e0', 'k', 'm'),
#                ('e0',)): Counter({('e0', True): 5, ('i0', True): 1}),
#               (('e0', 'k', 'n'), ('e0',)): Counter({('i0', True): 1}),
#               (('e0', 'k', 'o0'), ('e0', 'o0')): Counter({('ɾ', False): 2}),
#               (('e0', 'k', 's'),
#                ('e0',)): Counter({('i0', True): 3, ('t', False): 2}),
#               (('e0', 'k', 's'), ('e0', 'e0')): Counter({('', False): 2}),
#               (('e0', 'k', 's'), ('o0', 'e0')): Counter({('', False): 2}),
#               (('e0', 'k', 't'),
#                ('e0',)): Counter({('e0', True): 2,
#                        ('i0', True): 4,
#                        ('u0', True): 1,
#                        ('œ0', True): 2}),
#               (('e0', 'k', 't'), ('i0', 'e0')): Counter({('', False): 1}),
#               (('e0', 'k', 'tʃ'), ('e0',)): Counter({('o0', True): 1}),
#               (('e0', 'k', 'ɯ0'), ('e0', 'ɯ0')): Counter({('', False): 1}),
#               (('e0', 'k', 'ɾ'), ('e0',)): Counter({('a0', True): 2}),
#               (('e0', 'k', 'ʃ'), ('e0',)): Counter({('i0', True): 1}),
#               (('e0', 'k', 'ʲ'), ('e0',)): Counter({('a0', True): 2}),
#               (('e0', 'l'),
#                ('e0',)): Counter({('a0', True): 1,
#                        ('b', False): 1,
#                        ('d', False): 2,
#                        ('e0', True): 1,
#                        ('i0', True): 4,
#                        ('m', False): 2,
#                        ('tʃ', False): 1,
#                        ('z', False): 1}),
#               (('e0', 'l', 'a0'),
#                ('e0', 'a0')): Counter({('', False): 2,
#                        ('k', False): 1,
#                        ('l', False): 1,
#                        ('m', False): 2,
#                        ('ʃ', False): 1}),
#               (('e0', 'l', 'b'), ('e0',)): Counter({('e0', True): 1}),
#               (('e0', 'l', 'd'),
#                ('e0',)): Counter({('e0', True): 2, ('i0', True): 5}),
#               (('e0', 'l', 'e0'),
#                ('e0', 'e0')): Counter({('', False): 5,
#                        ('k', False): 1,
#                        ('n', False): 1,
#                        ('t', False): 1,
#                        ('ɾ', False): 2}),
#               (('e0', 'l', 'g'), ('e0',)): Counter({('e0', True): 2}),
#               (('e0', 'l', 'i0'),
#                ('e0', 'i0')): Counter({('', False): 4,
#                        ('f', False): 2,
#                        ('k', False): 2,
#                        ('l', False): 1,
#                        ('m', False): 2,
#                        ('n', False): 3,
#                        ('p', False): 3,
#                        ('ɾ', False): 2,
#                        ('ʃ', False): 1}),
#               (('e0', 'l', 'k'),
#                ('e0',)): Counter({('e0', True): 1, ('i0', True): 2}),
#               (('e0', 'l', 'm'),
#                ('e0',)): Counter({('a0', True): 2,
#                        ('e0', True): 3,
#                        ('i0', True): 2}),
#               (('e0', 'l', 's'),
#                ('e0',)): Counter({('e0', True): 1, ('i0', True): 2}),
#               (('e0', 'l', 'tʃ'),
#                ('e0',)): Counter({('i0', True): 1, ('l', False): 1}),
#               ...})}

# %% [markdown]
# ### 1.2 orig lexicon -> $log_2(Pr(syllen))$ in df_counts_bysyl

# %%
words_path = 'mono_di_5000/' + LanCode + '.mono.di.5000'

print(words_path)
words = pd.read_csv(words_path, sep="\t")
words["syllen"] = words.ipa.map(lambda x: syl_count(x))
words["seglen"] = words.ipa.map(lambda x: seg_count(x))
# Out:
# mono_di_5000/tr.mono.di.5000

# %%
# logprob for each syllable length according to the real orig lexicon
words_total_count = len(words)
df_counts_bysyl = words.groupby(['syllen']).size().reset_index(name = 'counts')
df_counts_bysyl['logprob'] = np.log2(df_counts_bysyl.counts/words_total_count)
#probs_syl3 = df_counts_bysyl.loc[df_counts_bysyl['syllen'] == 3].reset_index()

# %%
df_counts_bysyl
# Out:
#    syllen  counts   logprob
# 0       1     700 -2.952334
# 1       2    4718 -0.199585

# %% [markdown]
# ### 1.3 real lexicon used for counts in sampling -> len_usable_df

# %%
# 实际使用的orig lexicon
words_update = words[words.seglen <= num_max_segs]
# get sizes for every syllable length
syl_array = words_update["syllen"].unique()

wordlist_bysyl = {}
for syl_len in syl_array:
    wordlist_bysyl[syl_len] = words_update[words_update.syllen == syl_len]

# %%
words_update
# Out:
#                 ipa    word  freq  syllen  seglen
# 0       b y0 t y0 n   bütün   965       2       5
# 1            j e0 ɾ     yer   953       1       3
# 2       g e0 l e0 n   gelen   950       2       5
# 3         a0 d a0 m    adam   948       2       4
# 4       k a0 ɾ ʃ ɯ0   karşı   943       2       5
# ...             ...     ...   ...     ...     ...
# 5413         z a0 m     zam     6       1       3
# 5414    z a0 ɾ i0 f   zarif     6       2       5
# 5415    z o0 ɾ b a0   zorba     6       2       5
# 5416  z o0 ɾ l a0 ɾ  zorlar     6       2       6
# 5417       z ɯ0 ɾ t    zırt     6       1       4
#
# [5418 rows x 5 columns]

# %% [markdown]
# Get number of words with combinations of syl-seg lengths to sample according to

# %%
words_update_len = words_update[['syllen', 'seglen']]

# %%
#len_usable_df = words_update_len.pivot_table(index='syllen', 
#                             columns='seglen', 
#                             aggfunc=len,
#                             fill_value = 0)

# %%
len_usable_df = pd.DataFrame(
    words_update_len.groupby(
        [words_update_len['syllen'],
         words_update_len['seglen']]
    ).size()
).reset_index()

# %%
len_usable_df.columns = ['syllen', 'seglen', 'count']

# %%
len_usable_df
# Out:
#     syllen  seglen  count
# 0        1       1      7
# 1        1       2    133
# 2        1       3    408
# 3        1       4    141
# 4        1       5      9
# ..     ...     ...    ...
# 8        2       4   1143
# 9        2       5   2264
# 10       2       6   1065
# 11       2       7     87
# 12       2       8      9
#
# [13 rows x 3 columns]

# %% [markdown]
# ### 1.4 enum by syllable

# %%
syl_array
# Out:
# array([2, 1])

# %%
enum_path_base = 'mono_di_5000/bySyl/' + LanCode + '.enum.word.10.syl'
enum_bysyl = {}
for syl_len in syl_array:
    syl = pd.read_csv(enum_path_base + str(syl_len) + '.csv', sep = ',')
    syl.columns = ['ipa','seglen']
    # only keep words that match the number of syllables
    syl['syllen'] = syl['ipa'].apply(syl_count)
    syl_filtered = syl[syl['syllen'] == syl_len]
    enum_bysyl[syl_len] = syl_filtered

# %%
enum_words = pd.concat([enum_bysyl[i] for i in syl_array])

# %%
enum_words
# Out:
#                ipa  seglen  syllen
# 0      b y0 t y0 n       5       2
# 1        b y0 t y0       4       2
# 2      b y0 t y0 k       5       2
# 3     b y0 t tʃ e0       5       2
# 4    b y0 l b y0 l       6       2
# ..             ...     ...     ...
# 714         ʃ ɯ0 n       3       1
# 715       ʃ i0 ɾ k       4       1
# 716         ʃ i0 ʃ       3       1
# 717       ʒ e0 s t       4       1
# 718           ʒ i0       2       1
#
# [15046 rows x 3 columns]

# %%
enum_words_len = enum_words[['syllen', 'seglen']]

enum_len_usable_df = pd.DataFrame(
    enum_words_len.groupby(
        [enum_words_len['syllen'],
         enum_words_len['seglen']]
    ).size()
).reset_index()
enum_len_usable_df.columns = ['syllen', 'seglen', 'count']

# %%
enum_len_usable_df
# Out:
#     syllen  seglen  count
# 0        1       1      7
# 1        1       2    133
# 2        1       3    411
# 3        1       4    146
# 4        1       5     17
# ..     ...     ...    ...
# 8        2       4   2208
# 9        2       5   7210
# 10       2       6   3726
# 11       2       7    811
# 12       2       8    156
#
# [13 rows x 3 columns]

# %% [markdown]
# Compare the syl-seg combination counts in the real lexicon and enumerated words

# %%
enum_len_usable_df = enum_len_usable_df.astype({'syllen': 'int64', 'seglen': 'int64'})
len_usable_df_all = pd.merge(len_usable_df, enum_len_usable_df, on = ['syllen', 'seglen'])
len_usable_df_all.columns = ['syllen', 'seglen', 'count_orig', 'count_enum']
len_usable_df_all['lack_enum'] = (len_usable_df_all['count_enum'] - len_usable_df_all['count_orig']) < 0

# %%
len_usable_df_all
# Out:
#     syllen  seglen  count_orig  count_enum  lack_enum
# 0        1       1           7           7      False
# 1        1       2         133         133      False
# 2        1       3         408         411      False
# 3        1       4         141         146      False
# 4        1       5           9          17      False
# ..     ...     ...         ...         ...        ...
# 8        2       4        1143        2208      False
# 9        2       5        2264        7210      False
# 10       2       6        1065        3726      False
# 11       2       7          87         811      False
# 12       2       8           9         156      False
#
# [13 rows x 5 columns]

# %% [markdown]
# check if the enumerated combination counts are valid (enumerated words in each seg-syl combination are more than number of words in the real lexicon)

# %%
if sum(len_usable_df_all.lack_enum) > 0:
    print(LanCode, ": enumberated wordforms do not cover every word in the training lexicon")
    exit()

# %% [markdown]
# ## 2. Get a random language model and generate a new lexicon for each syllen

# %%
import os
# number of existing samples
#len([name for name in os.listdir('samples/tr')])
now = datetime.now()

# %%
new_sample = sampling_from_enum_with_dirichlet_lm(enum_bysyl, df_counts_bysyl, len_usable_df, lm_dict)

# %%
new_sample
#sample_writename = ('samples/' + 
#        LanCode + '/'
#        + 'sample.'
#        + str(now.month) + str(now.day) + '_' 
#        + str(now.hour) + str(now.minute) + str(now.second) 
#        + '_' + str(now.microsecond)
#        + '.bz2'
#        )
#sample_writename
#write to 'samples/tr' the new sample
#new_sample.to_csv(sample_writename, index = False, compression = 'bz2')
# Out:
#                      ipa    logprob  seglen  syllen
# 542                   u0 -12.408056       1       1
# 367                   y0 -12.387314       1       1
# 361                   ɯ0 -12.473917       1       1
# 658                  aː0 -12.330421       1       1
# 112                   i0 -12.370184       1       1
# ...                  ...        ...     ...     ...
# 8532   s t ɾ e0 n k s i0 -18.254735       8       2
# 3449   k o0 m p l e0 k s -12.459718       8       2
# 8278   s u0 ɾ p ɾ i0 z m -13.386633       8       2
# 13692  l a0 s t l a0 ɾ m -22.143592       8       2
# 8583   s p o0 ɾ t e0 k s -14.216778       8       2
#
# [5418 rows x 4 columns]
